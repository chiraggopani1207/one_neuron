# %%
"""1. Write a Python program to print Hello Python"""
print("Hello python!")
# Out:
# Hello python!

# %%
"""2. Write a Python program to do arithmetical operations addition and division.?"""
num1=int(input("Enter your desired number : "))
num2=int(input("Enter your desired number : "))
operator1 =input("choose from operator '+' or '-' : ")
if operator1=='+':
    print (num1 + num2)
elif operator1=='-':
    print (num1-num2)
else:
    print("invalid operator")
# Out:
# Enter your desired number : 12
# Enter your desired number : 13
# choose from operator '+' or '-' : +
# 25

# %%
"""3. Write a Python program to find the area of a triangle?"""
def area_triangle(H,B):
    return ("Area of triange is ",(H*B/2))

# %%
area_triangle(10,20)
# Out:
# ('Area of triange is ', 100.0)

# %%
"""4. Write a Python program to swap two variables?"""
a,b=5,7
print(a,b)
a,b=b,a
print(a,b)
# Out:
# 5 7
# 7 5

# %%
"""5. Write a Python program to generate a random number?"""
import random
x = random.randint(1,100)
print(x)
# Out:
# 75
