# %%
"""Q1. What is the purpose of Python&#39;s OOP?
A =object oriented programming is paradigm that provides structure and behaviour to bundel of object so they respond in similar fashion to real object
1 in python object oriented programming use object and classes
2 it aims to inherit real world entities like polymorphism,encapsulation,inheritence etc
3 the main purpose o creating object is that it binds the data and function togather so no part of code can acess it seperately
4 it divide our program in small segment so its easy to use
5 help in maintaining and modification of created objected
6 multiple inheritance of object can be masde"""
# Out:
# 'Q1. What is the purpose of Python&#39;s OOP?\nA =object oriented programming is paradigm that provides structure and behaviour to bundel of object so they respond in similar fashion to real object\n1 in python object oriented programming use object and classes\n2 it aims to inherit real world entities like polymorphism,encapsulation,inheritence etc\n3 the main purpose o creating object is that it binds the data and function togather so no part of code can acess it seperately\n4 it divide our program in small segment so its easy to use\n5 help in maintaining and modification of created objected\n6 multiple inheritance of object can be masde'

# %%
"""Q2. Where does an inheritance search look for an attribute?
A =python searches attribute in upward tree attribute. it searched in instance of calss then in the class from where its inherited and then in super class in which is part of"""
# Out:
# 'Q2. Where does an inheritance search look for an attribute?\nA =python searches attribute in upward tree attribute. it searched in instance of calss then in the class from where its inherited and then in super class in which is part of'

# %%
"""Q3. How do you distinguish between a class object and an instance object?
A =class is template for creating object where as object is instance of class
seperate memory location is created for each object but for class this not happens
class is created once while many objects are created using class
as class have no memory so they can not be manipulated"""
# Out:
# 'Q3. How do you distinguish between a class object and an instance object?\nA =class is template for creating object where as object is instance of class\nseperate memory location is created for each object but for class this not happens\nclass is created once while many objects are created using class\nas class have no memory so they can not be manipulated'

# %%
"""Q4. What makes the first argument in a class’s method function special?
A =python class have genrally 3 methods
class method
instance method
and static method
self is first argument in instance method and cls is first argument in class method"""
# Out:
# 'Q4. What makes\xa0the first argument in a class’s method function special?\nA =python class have genrally 3 methods\nclass method\ninstance method\nand static method\nself is first argument in instance method and cls is first argument in class method'

# %%
"""Q5. What is the purpose of the __init__ method?
A =__init__ method is reserved in python language.its serves role of constructor in object oriented terminology.
its used when object is created in class and to intialize its attributes"""
# Out:
# 'Q5. What is the purpose of the __init__ method?\nA =__init__ method is reserved in python language.its serves role of constructor in object oriented terminology.\nits used when object is created in class and to intialize its attributes'

# %%
"""Q6. What is the process for creating a class instance?
A =c1 =class_example("first","second"):
c1 is instance of class with attributed "first" and "second"."""
# Out:
# 'Q6. What is the process for creating a class instance?\nA =c1 =class_example("first","second"):\nc1 is instance of class with attributed "first" and "second".'

# %%
"""Q7. What is the process for creating a class?
A =class keywod is used in python to create class"""
# Out:
# 'Q7. What is the process for creating a class?\nA =class keywod is used in python to create class'

# %%
"""Q8. How would you define the superclasses of a class?
A =class car(vehicles):
here child class car takes attributes and method  from super class vehicles """
# Out:
# 'Q8. How would you define the superclasses of a class?\nA =class car(vehicles):\nhere child class car takes attributes and method  from super class vehicles '
