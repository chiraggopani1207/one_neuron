# %%
"""1. Is the Python Standard Library included with PyInputPlus?
A = NO pyInputplus is not inbuild library in python we need to install it seperately by !pip install pyInputplus"""
# Out:
# '1. Is the Python Standard Library included with PyInputPlus?\nA = NO pyInputplus is not inbuild library in python we need to install it seperately by !pip install pyInputplus'

# %%
"""2. Why is PyInputPlus commonly imported with import pyinputplus as pypi?
A = we can import the module pyInputplus as pypi so when need arise we can call for short name"""
# Out:
# '2. Why is PyInputPlus commonly imported with import pyinputplus as pypi?\nA = we can import the module pyInputplus as pypi so when need arise we can call for short name'

# %%
"""3. How do you distinguish between inputInt() and inputFloat()?
A =inputint() will always returns values in integer and additionally it takes min,max,greater than and less then parameters
inputfloat() will always returns values in float and additionally it takes min,max,greater than and less then parameters"""
# Out:
# '3. How do you distinguish between inputInt() and inputFloat()?\nA =inputint() will always returns values in integer and additionally it takes min,max,greater than and less then parameters\ninputfloat() will always returns values in float and additionally it takes min,max,greater than and less then parameters'

# %%
"""4. Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99?
A = we can use inputint() function to ensure it provides us whole number only and for range we can use min and max function"""
import pyinputplus as pyip
whole_num = pyip.inputint(prompt="enter a number",min=0,max=100)
print(whole_num)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-796e34ca9483> in <module>
#       1 """4. Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99?
#       2 A = we can use inputint() function to ensure it provides us whole number only and for range we can use min and max function"""
# ----> 3 import pyinputplus as pyip
#       4 whole_num = pyip.inputint(prompt="enter a number",min=0,max=100)
#       5 print(whole_num)
#
# ModuleNotFoundError: No module named 'pyinputplus'

# %%
"""5. What is transferred to the keyword arguments allowRegexes and blockRegexes?
A =we can use allowregexes and blockregexes expression to determine which strings will be accepted and which one will be rejected"""
# Out:
# '5. What is transferred to the keyword arguments allowRegexes and blockRegexes?\nA =we can use allowregexes and blockregexes expression to determine which strings will be accepted and which one will be rejected'

# %%
"""6. If a blank input is entered three times, what does inputStr(limit=3) do?
A =the statement inputstr(limit=3)will throw 2 exceptions validation exception and retrylimitexception
first ecxeption is thrown because blank values are not allowed by default if you wish to allow blank then you have to pass blank=True
second exception thrown when maximum limit of retry is reached"""
# Out:
# '6. If a blank input is entered three times, what does inputStr(limit=3) do?\nA =the statement inputstr(limit=3)will throw 2 exceptions validation exception and retryexception\nfirst ecxeption is thrown because blank values are not allowed by default if you wish to allow blank then you have to pass blank=True\nsecond exception thrown when maximum limit of retry is reached'

# %%
"""7. If blank input is entered three times, what does inputStr(limit=3, default'hello') do?
A = if blank input is passed 3 times then it will return default value set as parameter "hello" """
# Out:
# '7. If blank input is entered three times, what does inputStr(limit=3, default\'hello\') do?\nA = if blank input is passed 3 times then it will return default value set as parameter "hello" '
