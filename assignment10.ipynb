# %%
"""1. How do you distinguish between shutil.copy() and shutil.copytree()?
A =shutil.copy() is primarily use to copy file data and paste in other file.it takes 2 arguments(src.dest) where src refers to content of file
and dest refers to destination path of the file
shutil.copytree() is used for copying the whole folder to another destination"""
# Out:
# '1. How do you distinguish between shutil.copy() and shutil.copytree()?\nA =shutil.copy() is primarily use to copy file data and paste in other file.it takes 2 arguments(src.dest) where src refers to content of file\nand dest refers to destination path of the file\nshutil.copytree() is used for copying the whole folder to another destination'

# %%
"""2. What function is used to rename files??
A =os.rename(src,dest) is function to rename any file"""
# Out:
# '2. What function is used to rename files??\nA =os.rename(src,dest) is function to rename any file'

# %%
"""3. What is the difference between the delete functions in the send2trash and shutil modules?
A =  to delete any file we can use os.remove() and os.rmdir() this function will permanently delet file and we can not recover it later
while send2trash.send2trash() will send file or folder to recycle bin of your computer from where we can again recover file"""
# Out:
# '3. What is the difference between the delete functions in the send2trash and shutil modules?\nA =  to delete any file we can use os.remove() and os.rmdir() this function will permanently delet file and we can not recover it later\nwhile send2trash.send2trash() will send file or folder to recycle bin of your computer from where we can again recover file'

# %%
"""4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is
equivalent to File objects’ open() method?
A =zipfile.zipfile() module is used read and write any zip file. It take arguments like ("filename.txt","r")
zipfile.zipfile("filename.txt","r+")"""
# Out:
# '4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is\nequivalent to File objects’ open() method?\nA =zipfile.zipfile() module is used read and write any zip file. It take arguments like ("filename.txt","r")\nzipfile.zipfile("filename.txt","r+")'

# %%
"""5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf
or .jpg). Copy these files from whatever location they are in to a new folder.
A """
# Out:
# '5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf\nor .jpg). Copy these files from whatever location they are in to a new folder.\nA '

# %%
import os
import shutil

def search_and_copy(source,destination,extensions):
    source = os.path.abspath(source)
    destination = os.path.abspath(destination)
    for foldername, subfolder, filenames in os.walk(source):
        print(f'Folder Name ➞ {foldername}',end='\n\n')
        print(f'Sub Folders ➞ {subfolder}',end='\n\n')
        print(f'Files ➞ {filenames}',end='\n\n')
        for filename in filenames:
            fileName,extension = os.path.splitext(filename)
            if extension in extensions:
                targetFile = foldername+os.path.sep+fileName+extension
                shutil.copy(targetFile, destination)
        print(f'Files copied successfully from {source} to {destination}')
    
extensions = ['.pdf','.jpg','.ipynb']
source = 'Dummy Source'
destination = 'Dummy Destination'
search_and_copy(source, destination, extensions)
