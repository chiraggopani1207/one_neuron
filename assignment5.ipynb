# %%
"""1. What does an empty dictionary"s code look like?
dic1 = {},dictionary is represented in curly brackets"""
# Out:
# '1. What does an empty dictionary&#39;s code look like?\ndic1 = {},dictinary is represented in curly brackets'

# %%
"""2. What is the value of a dictionary value with the key ;foo and the value 42?
dict1 = {"foo":"42"}"""
# Out:
# '2. What is the value of a dictionary value with the key ;foo and the value 42?\ndict1 = {"foo":"42"}'

# %%
"""3. What is the most significant distinction between a dictionary and a list?
dictionary : comes in key and value pair and in unordered manner,same key and value pair can not be stored,
list : ordered manner data is stored,same data can be stored multiple times"""
# Out:
# '3. What is the most significant distinction between a dictionary and a list?\ndictionary : comes in key and value pair and in unordered manner,same key and value pair can not be stored,\nlist : ordered manner data is stored,same data can be stored multiple times'

# %%
"""4. What happens if you try to access spam["foo"] if spam is {bar: 100}?
this program will throw error as value does not exist is dictionary"""
# Out:
# '4. What happens if you try to access spam["foo"] if spam is {bar: 100}?\nthis program will throw error as value does not exist is dictionary'

# %%
"""5. If a dictionary is stored in spam, what is the difference between the expressions cat in spam and
cat in spam.keys()?
operation will search for keys name cat in both cases"""
# Out:
# '5. If a dictionary is stored in spam, what is the difference between the expressions cat in spam and\ncat in spam.keys()?\noperation will search for keys name cat in both cases'

# %%
"""6. If a dictionary is stored in spam, what is the difference between the expressions cat in spam and
cat in spam.values()?
peration will search for values name cat in both cases"""
# Out:
# '6. If a dictionary is stored in spam, what is the difference between the expressions cat in spam and\ncat in spam.values()?\nperation will search for values name cat in both cases'

# %%
"""7. What is a shortcut for the following code?
if color not in spam:
spam["color"] = "black
A =spam.setdefault('color':'black')"""
# Out:
# '7. What is a shortcut for the following code?\nif color not in spam:\nspam["color"] = "black\nA =spam.setdefault(\'color\':\'black\')'

# %%
"""8. How do you 'pretty print' dictionary values using which module and function?
"""

emp_data =[{"name" : "chirag","age" : "29","edu" :"graduate","occupation":{"company":"sharekhan":"city":" mumbai"}},
         {"name" : "ram","age" : "28","edu" :"data scientist","occupation" :{"company":"tcs":"city":" banglore"}},
           {"name" : "shyam","age" : "30","edu" :"m tech","occupation": {"company":"HAL":"city":" vizag"}}]

# %%
emp_data =[
    {"name" : "chirag","age" : "29","edu" :"graduate","occupation":{"company":"sharekhan":"city":" mumbai"}},
         {"name" : "ram","age" : "28","edu" :"data scientist","occupation" :{"company":"tcs":"city":" banglore"}},
           {"name" : "shyam","age" : "30","edu" :"m tech","occupation": {"company":"HAL":"city":" vizag"}}
]

# %%
import pprint
import json
import yaml

# %%
pprint.pprint(emp_data)

# %%
dump1 = json.dumps(emp_data)

# %%
print(emp_data)

# %%
"""please explain error code is not running"""
