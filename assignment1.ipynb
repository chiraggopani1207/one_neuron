# %%
l1=["+","-","*","/","-87.6","hello",int(90)]

# %%
l1
# Out:
# ['+', '-', '*', '/', -87.6, 'hello']

# %%
for i in l1:
    if i=="+" or i=="-" or i=="*" or i=="/":
        print("This is mathematical expression")
    elif i==str(i):
        print("this is string")
    elif i==int(i):
        print("this is integer type")
    else:
        print("invalid input")
# Out:
# This is mathematical expression
# This is mathematical expression
# This is mathematical expression
# This is mathematical expression
# this is string
# this is string
# this is integer type

# %%
Q = "What is the difference between string and variable?"
A = "variable is like container where any data type or values are stored while string is collection of data stored in single or double strings"

# %%
Q = "Describe three different data types."
A = "Boolean,Intigers,strings,list,Tuple,Dictionary,set"

# %%
Q = "What is an expression made up of? What do all expressions do?"
A = "expression is combination of operator and operand which are used to get results to particular problem."

# %%
spam = 10
"in above case spam is assigned 10 values which will  return 10 after execution"
"diffrence between expression and statement is after execution of expression it will return result while statement will not return anything."
# Out:
# 'diffrence between expression and statement is after execution of expression it will return result while statement will not return anything.'

# %%
bacon = 22
bacon + 1
"""we will receive 23 as value, 1 is added in previous values stored"""
# Out:
# 'we will receive 23 as value, 1 is added in previous values stored'

# %%
"spam" + "spamspam"
# Out:
# 'spamspamspam'

# %%
"spam" *3
#we will receive same results for both expressions given
# Out:
# 'spamspamspam'

# %%
Q = "Why is eggs a valid variable name while 100 is invalid?"
A= "thumb rule in python says variable name can not start with numeric value"

# %%
Q ="""What three functions can be used to get the integer, floating-point number, or string
version of a value?"""
A =""" Following inbuild fuction can be used, int(i) for integer // float(i) for floating number // str(i) for string values"""

# %%
Q = """Why does this expression cause an error? How can you fix it?
I have eaten" + 99 +  burritos."""
A = "We can see concatination problem in above statement where string and integer value can cont be joined"
Solution = ("i have eaten  " + str(99) + "  burritos")
print(Solution)
# Out:
# i have eaten  99  burritos
