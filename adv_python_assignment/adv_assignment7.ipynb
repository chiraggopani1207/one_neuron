# %%
"""Q1. What is the purpose of the try statement?
A =Try method is used in file handaling .it contains block of risky statement which causes program to throw error during runtime
if code raised any exception then it will rediected to the exception block.in short try and except is union of methods to avode crashing of program at the runtime

"""
try:
    print(10/0)
except ZeroDivisionError:
    print('Division by Zero is Not Possible')
# Out:
# Division by Zero is Not Possible

# %%
"""Q2. What are the two most popular try statement variations?
A =popular try statements are :
try,except
try,except,finally
try,except,finally,else
try block is used to check exception in code at runtime i.e try block will run when there is no error in statement
whereas code will raise else only and only if try and exception block does not raise exception
finally will execute irrespective of try and except block result"""
# Out:
# 'Q2. What are the two most popular try statement variations?\nA =popular try statements are :\ntry,except\ntry,except,finally\ntry,except,finally,else\ntry block is used to check exception in code at runtime i.e try block will run when there is no error in statement\nwhereas code will raise else only and only if try and exception block does not raise exception\nfinally will execute irrespective of try and except block result'

# %%
"""Q3. What is the purpose of the raise statement?
A = raise statement is used to raise exception explicitly,if certain condition of program is not as per requirement.
raise statement helps in triggering exception as per progam logic"""
# Out:
# 'Q3. What is the purpose of the raise statement?\nA = raise statement is used to raise exception explicitly,if certain condition of program is not as per requirement.\nraise statement helps in triggering exception as per progam logic'

# %%
"""Q4. What does the assert statement do, and what other statement is it like?
A =there are few assertion that program always wants to be true to avoide code failure 
this type of requirement is fulfilled by assertion statement.
this staement takes boolean condition of statement if its false then will raise assertion error"""
assert(2==4),f'This is wrong statement'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-429d01f999ad> in <module>
#       3 this type of requirement is fulfilled by assertion statement.
#       4 this staement takes boolean condition of statement if its false then will raise assertion error"""
# ----> 5 assert(2==4),f'This is wrong statement'
#
# AssertionError: This is wrong statement

# %%
"""Q5. What is the purpose of the with/as argument, and what other statement is it like?
A =with/as statement simplifies use of python for file handling when we use with statement in file handling there is no need for proggram to use explicit commands to open and close files
with statement ensures proper aquasition and alloction of resouces this avoide triggering of exception in file handling"""
# Out:
# 'Q5. What is the purpose of the with/as argument,\xa0and what other statement is it like?\nA =with/as statement simplifies use of python for file handling when we use with statement in file handling there is no need for proggram to use explicit commands to open and close files\nwith statement ensures proper aquasition and alloction of resouces this avoide triggering of exception in file handling'

# %%
with open("hello.txt","w")as file:
    i=file.write("Hello world!")
    print(i)
    print(file.readlines)
# Out:
# 12
# <built-in method readlines of _io.TextIOWrapper object at 0x7f3782fda048>
