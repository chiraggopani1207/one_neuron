# %%
"""Q1. Describe the differences between text and binary files in a single paragraph.
A = Text file are special subset of binary file which are in human readable form as rich text document or plain text document.text file also stores sequential data bytes but bits in text file represents chaacter.

binary file are those typical type of file which stores data in form of sequence of bytes grouped in to eight bits or sometime in sixteen bits.
these files stores custome data and sometime shows multiple types of data(image,audio,text etc)"""
# Out:
# 'Q1. Describe the differences between text and binary files in a single paragraph.\nA = Text file are special subset of binary file which are in human readable form as rich text document or plain text document.text file also stores sequential data bytes but bits in text file represents chaacter.\n\nbinary file are those typical type of file which stores data in form of sequence of bytes grouped in to eight bits or sometime in sixteen bits.\nthese files stores custome data and sometime shows multiple types of data(image,audio,text etc)'

# %%
"""Q2. What are some scenarios where using text files will be the better option? When would you like to
use binary files instead of text files?
A =text file are less prone to get corrupted as any undesired change just shows up while opening file and it can be easily alter.
where as use binry file instead of text to show image data."""
# Out:
# 'Q2. What are some scenarios where using text files will be the better option? When would you like to\nuse binary files instead of text files?\nA =text file are less prone to get corrupted as any undesired change just shows up while opening file and it can be easily alter.\nwhere as use binry file instead of text to show image data.'

# %%
"""Q3. What are some of the issues with using binary operations to read and write a Python integer
directly to disc?
A =1)Binary file deals with raw data
2)one need to identify how many bytes one shouls read and write"""
# Out:
# 'Q3. What are some of the issues with using binary operations to read and write a Python integer\ndirectly to disc?\nA =1)Binary file deals with raw data\n2)one need to identify how many bytes one shouls read and write'

# %%
"""Q4. Describe a benefit of using the with keyword instead of explicitly opening a file.
A =when file is open with using with keyword if any exception or error occured then we do not have to explicitly close the file 
program always close the file automatically and does not keep file open"""
# Out:
# 'Q4. Describe a benefit of using the with keyword instead of explicitly opening a file.\nA =when file is open with using with keyword if any exception or error occured then we do not have to explicitly close the file \nprogram always close the file automatically and does not keep file open'

# %%
"""Q5. Does Python have the trailing newline while reading a line of text? Does Python append a
newline when you write a line of text?
A =yes python have trailing new line while reading a line of text.we have to explicitly give newline comand while writing newline"""
# Out:
# 'Q5. Does Python have the trailing newline while reading a line of text? Does Python append a\nnewline when you write a line of text?\nA =yes python have trailing new line while reading a line of text.we have to explicitly give newline comand while writing newline'

# %%
"""Q6. What file operations enable for random-access operation?
A =the random operation in file handling are seek() and tell()"""
# Out:
# 'Q6. What file operations enable\xa0for random-access operation?\nA =the random operation in file handling are seek() and tell()'

# %%
"""Q7. When do you think you'll use the struct package the most?
A =The struct package is used when we need to convert python file to C language."""
# Out:
# "Q7. When do you think you'll use the struct package the most?\nA =The struct package is used when we need to convert python file to C language."

# %%
"""Q8. When is pickling the best option?
A =picking is best option while creating new binary file in python"""
# Out:
# 'Q8. When is pickling the best option?\nA =picking is best option while creating new binary file in python'

# %%
"""Q9. When will it be best to use the shelve package?
A =shelve package is use to pickels the data but treat whole file as dictionary"""
# Out:
# 'Q9. When will it be best to use the shelve package?\nA =shelve package is use to pickels the data but treat whole file as dictionary'

# %%
"""Q10. What is a special restriction when using the shelve package, as opposed to using other data
dictionaries?
A =Only string data type can be used as key in this special dictionary object, whereas any picklable Python object can be used as value."""
# Out:
# 'Q10. What is a special restriction when using the shelve package, as opposed to using other data\ndictionaries?\nA =Only string data type can be used as key in this special dictionary object, whereas any picklable Python object can be used as value.'
