# %%
"""1. What is the concept of an abstract superclass?
a =An abstract/superclass is considered blue prit for other classes. It allows you to create the method which are necessary for child classes.
A class which contains one or more abstract methods is called abstract or super class"""
# Out:
# '1. What is the concept of an abstract superclass?\na =An abstract/superclass is considered blue prit for other classes. It allows you to create the method which are necessary for child classes.\nA class which contains one or more abstract methods is called abstract or super class'

# %%
"""2. What happens when a class statements top level contains a basic assignment statement?
A =when class statement's top level contains assignment statement it is considered as class attribute or class level attribute
where as assignment statement traeted as instances or local attribute
when instance is created single copy of attribute is created and shareed to all instances of class"""
class human:
    spieces : "homosepiens"
    def __init__(self,name,age):
        self.name=name
        self.age=age

# %%
"""3. Why does a class need to manually call a superclass's __init__ method?
A =IF child class has __init__ method then it will not inherite from super class , in simple words init method of child class overrides init method of super class
so we have to manually call cuper class by super__init__()
"""
class emp:
    def __init__(self,name,age):
        self.name=name
        self.age=age
class subordinate(emp):
    def __init__(self,name,age,salary):
        super().__init__(name,age):
            self.salary=salary
emp1=emp("rahul",28,30000)
print(emp1__dict__)

# %%
"""4. How can you augment, instead of completely replacing, an inherited method?
A =super method can be used as argument instead of completely replacing inherit method """
class Person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender
class Employee(Person):
    def __init__(self,name,gender,salary):
        super().__init__(name,gender) 
        self.salary = salary
emp_1 = Employee('Vivek','Male',10000)
print(emp_1.__dict__)

# %%
"""5. How is the local scope of a class different from that of a function?
A =a variable inside a function is not accessible outside function range from starting def to exit of function

similarly a variable inside of a class is limited to class scope"""
def hello(name):
    name = name
    print(f'you\'re name is {name}')
hello('Mano Vishnu')
try:
    name
except NameError:
    print('Name varible is not available outside hello function scope')

class Person:
    species = "HomeSapines"
    def __init__(self):
        pass
print(Person.species) # Accessing species using class name
Male = Person()
print(Male.species) # Accessing species using instance of class
