# %%
"""Q1. What are the benefits of the built-in array package, if any?
A =array represents multiple data of same type using a single name.
in arrays,element can be accessed randomly by using index number.arrays allocate memory in contogous locations of all its elements.
hence there is no chance of extra memory allocation in arrays.this avoids memory overflow or shortage of memory in arrays."""
# Out:
# 'Q1. What are the benefits of the built-in array package, if any?\nA =array represents multiple data of same type using a single name.\nin arrays,element can be accessed randomly by using index number.arrays allocate memory in contogous locations of all its elements.\nhence there is no chance of extra memory allocation in arrays.this avoids memory overflow or shortage of memory in arrays.'

# %%
"""Q2. What are some of the array package's limitations?
A=the number of elements to be stored in arrays should be known in advance.An array is static structure which means array is of fixed size.
once declared array can not be modified.
memory can not be increased or decresed in array later.
insertion and deletion in arrays are quiet difficult as elements are stored in consicutive mmory location and shifting is very costly.
allocaion more memory than requirement leads to wastage of memory and less allocation leads to problem."""
# Out:
# "Q2. What are some of the array package's limitations?\nA=the number of elements to be stored in arrays should be known in advance.An array is static structure which means array is of fixed size.\nonce declared array can not be modified.\nmemory can not be increased or decresed in array later.\ninsertion and deletion in arrays are quiet difficult as elements are stored in consicutive mmory location and shifting is very costly.\nallocaion more memory than requirement leads to wastage of memory and less allocation leads to problem."

# %%
"""Q3. Describe the main differences between the array and numpy packages.
A =the array package does not provide any help with numerical calculation with the items inside while numpy gives various numerical function .
an array is single dimension data while numpy can have more than 1 dimension
in case of array it can be accssed through its index number so its easy to get but in numpy to get any item you need row and column indexes which is little complicated.
in case of numpy we create tabular structure and array is not in tabular form"""
# Out:
# 'Q3. Describe the main differences between the array and numpy packages.\nA =the array package does not provide any help with numerical calculation with the items inside while numpy gives various numerical function .\nan array is single dimension data while numpy can have more than 1 dimension\nin case of array it can be accssed through its index number so its easy to get but in numpy to get any item you need row and column indexes which is little complicated.\nin case of numpy we create tabular structure and array is not in tabular form'

# %%
"""Q4. Explain the distinctions between the empty, ones, and zeros functions.
A =the distribution between empty,zero and one functions are as below
empty function is function that does not contain any statement inside or return any thing.when you have to to create function that does nothing you have to use pass function where it will not genrate error while calling the function.
one function will return new array and data type where value is 1
zero function will return new array of shape and data type where value is 0"""
# Out:
# 'Q4. Explain the distinctions between the empty, ones, and zeros functions.\nA =the distribution between empty,zero and one functions are as below\nempty function is function that does not contain any statement inside or return any thing.when you have to to create function that does nothing you have to use pass function where it will not genrate error while calling the function.\none function will return new array and data type where value is 1\nzero function will return new array of shape and data type where value is 0'

# %%
"""Q5. In the fromfunction function, which is used to construct new arrays, what is the role of the callable
argument?
A =its function is to cordinate and execute the function over each array.function is called with n parameters.where n is rank of shape.
each parameter coordinate varying along the axis """
# Out:
# 'Q5. In the fromfunction function, which is used to construct new arrays, what is the role of the callable\nargument?\nA =its function is to cordinate and execute the function over each array.function is called with n parameters.where n is rank of shape.\neach parameter coordinate varying along the axis '

# %%
"""Q6. What happens when a numpy array is combined with a single-value operand (a scalar, such as
an int or a floating-point value) through addition, as in the expression A + n?
A =if any scalar value is added in numpy array then its value is added in all the elements inside array"""
# Out:
# 'Q6. What happens when a numpy array is combined with a single-value operand (a scalar, such as\nan int or a floating-point value) through addition, as in the expression A + n?\nA =if any scalar value is added in numpy array then its value is added in all the elements inside array'

# %%
"""Q7. Can array-to-scalar operations use combined operation-assign operators (such as += or *=)?
What is the outcome?
A =it will carry out provide on all elements of array."""
# Out:
# 'Q7. Can array-to-scalar operations use combined operation-assign operators (such as += or *=)?\nWhat is the outcome?\nA =it will carry out provide on all elements of array.'

# %%
"""Q8. Does a numpy array contain fixed-length strings? What happens if you allocate a longer string to
one of these arrays?
A =es, it is possible that we can include a string of fixed length in numpy array. The dtype of any numpy array containing string values is the maximum length of any string present in the array.Once set, it will only be able to store new string having length not more than the maximum length at the time of the creation. If we try to reassign some another string value having length greater than the maximum length of the existing elements, it simply discards all the values beyond the maximum length accept upto those values which are under the limit."""
# Out:
# 'Q8. Does a numpy array contain fixed-length strings? What happens if you allocate a longer string to\none of these arrays?\nA =es, it is possible that we can include a string of fixed length in numpy array. The dtype of any numpy array containing string values is the maximum length of any string present in the array.Once set, it will only be able to store new string having length not more than the maximum length at the time of the creation. If we try to reassign some another string value having length greater than the maximum length of the existing elements, it simply discards all the values beyond the maximum length accept upto those values which are under the limit.'

# %%
"""Q9. What happens when you combine two numpy arrays using an operation like addition (+) or
multiplication (*)? What are the conditions for combining two numpy arrays?
A = it will simply multiply or add element to element in same position"""
# Out:
# 'Q9. What happens when you combine two numpy arrays using an operation like addition (+) or\nmultiplication (*)? What are the conditions for combining two numpy arrays?\nA = it will simply multiply or add element to element in same position'

# %%
"""Q10. What is the best way to use a Boolean array to mask another array?
A =the best way to use a Boolean array to mask another array by using mask_where of numpy package."""
# Out:
# 'Q10. What is the best way to use a Boolean array to mask another array?\nA =the best way to use a Boolean array to mask another array by using mask_where of numpy package.'

# %%
"""Q11. What are three different ways to get the standard deviation of a wide collection of data using
both standard Python and its packages? Sort the three of them by how quickly they execute.
A =np.std and math package can be used individually."""
# Out:
# 'Q11. What are three different ways to get the standard deviation of a wide collection of data using\nboth standard Python and its packages? Sort the three of them by how quickly they execute.\nA =np.std and math package can be used individually.'

# %%
"""12. What is the dimensionality of a Boolean mask-generated array?
A =it will have sam simensionality as input in array."""
# Out:
# '12. What is the dimensionality of a Boolean mask-generated array?\nA =it will have sam simensionality as input in array.'
