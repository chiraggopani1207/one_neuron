# %% [markdown]
# # Welcome to Jupyter!

# %%
"""Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you
predict them at all?
A =A probability distribution show how random variables aare distributed.
it tells us which value random variable most likely to take on and which values are unlikely to get selected.
based on the previous data of random occurence we can predict outcome in terms of probability."""
# Out:
# 'Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you\npredict them at all?\nA =A probability distribution show how random variables aare distributed.\nit tells us which value random variable most likely to take on and which values are unlikely to get selected.\nbased on the previous data of random occurence we can predict outcome in terms of probability.'

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %%
"""Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is
one? Why are the latter considered “good enough”?
A =true random numbers are real random numbers while pseudo -random numbers are generated internally in program.later is called good enough as it have sort of uniform distribution."""
# Out:
# 'Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is\none? Why are the latter considered “good enough”?\nA =true random numbers are real random numbers while pseudo -random numbers are generated internally in program.later is called good enough as it have sort of uniform distribution.'

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook

# %%
"""Q3. What are the two main factors that influence the behaviour of a normal probability distribution?
A =there are two factors which affects normal probability distribution is mean and variance."""
# Out:
# 'Q3. What are the two main factors that influence the behaviour of a normal probability distribution?\nA =there are two factors which affects normal probability distribution is mean and variance.'

# %%
"""Q4. Provide a real-life example of a normal distribution.
A =real life example of normal distribution is levels of blood presure and heights of individuals"""
# Out:
# 'Q4. Provide a real-life example of a normal distribution.\nA =real life example of normal distribution is levels of blood presure and heights of individuals'

# %%
"""Q5. In the short term, how can you expect a probability distribution to behave? What do you think will
happen as the number of trials grows?
A =variance will decrease with number of trials"""
# Out:
# 'Q5. In the short term, how can you expect a probability distribution to behave? What do you think will\nhappen as the number of trials grows?\nA =variance will decrease with number of trials'

# %%
"""Q6. What kind of object can be shuffled by using random.shuffle?
A =list(list),tuple(tuple) and str(str) can be shuffled using random.shuffle"""
# Out:
# 'Q6. What kind of object can be shuffled by using random.shuffle?\nA =list(list),tuple(tuple) and str(str) can be shuffled using random.shuffle'

# %%
"""Q7. Describe the math packag's general categories of functions.
A =-->trignometric function
-->quadratic functions
-->exponential function
-->hyperbolic function
-->periodic function
-->arithmatic function
-->logarithamic function
-->conversion to integer"""
# Out:
# "Q7. Describe the math packag's general categories of functions.\nA =-->trignometric function\n-->quadratic functions\n-->exponential function\n-->hyperbolic function\n-->periodic function\n-->arithmatic function\n-->logarithamic function\n-->conversion to integer"

# %%
"""Q8. What is the relationship between exponentiation and logarithms?
A =exponential and logarithms are inversly propertionate to each other
"""
# Out:
# 'Q8. What is the relationship between exponentiation and logarithms?\nA =exponential and logarithms are inversly propertionate to each other\n'

# %%
"""Q9. What are the three logarithmic functions that Python supports?
A =log2(x)-logarithamic value of x to base 2
log10(x)-logarithamic value of x to base 10
log1p(a)-this function used to find logaritahms of (1+a)"""
# Out:
# 'Q9. What are the three logarithmic functions that Python supports?\nA =log2(x)-logarithamic value of x to base 2\nlog10(x)-logarithamic value of x to base 10\nlog1p(a)-this function used to find logaritahms of (1+a)'
