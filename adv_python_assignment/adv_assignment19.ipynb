# %% [markdown]
# # Welcome to Jupyter!

# %%
"""Q1. Define the relationship between a class and its instances. Is it a one-to-one or a one-to-many
partnership, for example?
A =relationship between class and instance is one to many partnership"""
# Out:
# 'Q1. Define the relationship between a class and its instances. Is it a one-to-one or a one-to-many\npartnership, for example?\nA =relationship between class and instance is one to many partnership'

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %%
"""Q2. What kind of data is held only in an instance?
A =instance objects hold specific variable which are related to only that instance"""
# Out:
# 'Q2. What kind of data is held only in an instance?\nA =instance objects hold specific variable which are related to only that instance'

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook

# %%
"""Q3. What kind of knowledge is stored in a class?
A =class creates user define data structure,which holds its own data member functions.which can be access by creating instance of that class
class is like blueprint of object"""
# Out:
# 'Q3. What kind of knowledge is stored in a class?\nA =class creates user define data structure,which holds its own data member functions.which can be access by creating instance of that class\nclass is like blueprint of object'

# %%
"""Q4. What exactly is a method, and how is it different from a regular function?
A =the method in class can be use to access instance variable of its instances.so object's state can be modified by its method.
functions cant access the attributes of instance's or modify object of class"""
# Out:
# "Q4. What exactly is a method, and how is it different from a regular function?\nA =the method in class can be use to access instance variable of its instances.so object's state can be modified by its method.\nfunctions cant access the attributes of instance's or modify object of class"

# %%
"""Q5. Is inheritance supported in Python, and if so, what is the syntax?
A =yes python supports instances
-->multiple inheritance
-->multilevel inheritance
-->simple inheritance
-->hybrid inheritance
-->hirarrical inheritance"""
class person:
    def __init__(self,fname,lname):
        self.fname=firstname
        self.lname=lastname
    def student(person):
        pass

# %%
"""Q6. How much encapsulation (making instance or class variables private) does Python support?
A =encapsulation describe the idea of wraping the data and method inside data in one unit.
these put restriction on accessing the variable and method directly and prevents accidental modification of data.
to prevent modification of method object data can be changed only by object method"""
# Out:
# 'Q6. How much encapsulation (making instance or class variables private) does Python support?\nA =encapsulation describe the idea of wraping the data and method inside data in one unit.\nthese put restriction on accessing the variable and method directly and prevents accidental modification of data.\nto prevent modification of method object data can be changed only by object method'

# %%
"""Q7. How do you distinguish between a class variable and an instance variable?
A =the class attibute is available to all instance of the class while object instance is limited to object or intance of that class.
a single copy of class attributes are maintained in pvm at the class level.
whreas different attributes of class and objects are maintained at pvm at object/instance level"""
# Out:
# 'Q7. How do you distinguish between a class variable and an instance variable?\nA =the class attibute is available to all instance of the class while object instance is limited to object or intance of that class.\na single copy of class attributes are maintained in pvm at the class level.\nwhreas different attributes of class and objects are maintained at pvm at object/instance level'

# %%
"""Q8. When, if ever, can self be included in a class's method definitions?
A =yes self method can be included when we want to access instance variable of class method."""
# Out:
# "Q8. When, if ever, can self be included in a class's method definitions?\nA =yes self method can be included when we want to access instance variable of class method."

# %%
"""Q9. What is the difference between the _ _add_ _ and the _ _radd_ _ methods?
A =before entering __radd__ python will use __add__ method to insert and if chages are not implemented than python will check right hand operand __radd__
and if does then it will __radd__ rather then raising Type error"""
# Out:
# 'Q9. What is the difference between the _ _add_ _ and the _ _radd_ _ methods?\nA =before entering __radd__ python will use __add__ method to insert and if chages are not implemented than python will check right hand operand __radd__\nand if does then it will __radd__ rather then raising Type error'

# %%
"""Q10. When is it necessary to use a reflection method? When do you not need it, even though you
support the operation in question?
A =reflection method we often encounter that a method in the executing the object or variable in calling object.or field of object
should be assigned while the method name or field name can not be determined whn encoding the code.
and need to be input in method of passing string through parameteres."""
# Out:
# 'Q10. When is it necessary to use a reflection method? When do you not need it, even though you\nsupport the operation in question?\nA =reflection method we often encounter that a method in the executing the object or variable in calling object.or field of object\nshould be assigned while the method name or field name can not be determined whn encoding the code.\nand need to be input in method of passing string through parameteres.'

# %%
"""Q11. What is the _ _iadd_ _ method called?
A =__iadd__ method is called when we want to perform methods like a += b a.__iadd__(b)"""
# Out:
# 'Q11. What is the _ _iadd_ _ method called?\nA =__iadd__ method is called when we want to perform methods like a += b a.__iadd__(b)'

# %%
"""Q12. Is the _ _init_ _ method inherited by subclasses? What do you do if you need to customize its
behavior within a subclass?
A =yes __inti__ method can be inherited in subclass if we want to customize its behaviour then we need to use super() class method"""
# Out:
# 'Q12. Is the _ _init_ _ method inherited by subclasses? What do you do if you need to customize its\nbehavior within a subclass?\nA =yes __inti__ method can be inherited in subclass if we want to customize its behaviour then we need to use super() class method'
