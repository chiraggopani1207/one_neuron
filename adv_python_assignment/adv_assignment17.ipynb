# %%
"""Q1. Explain the difference between greedy and non-greedy syntax with visual terms in as few words
as possible. What is the bare minimum effort required to transform a greedy pattern into a non-greedy
one? What characters or characters can you introduce or change?
A =the main difference between greedy and non geedy syntax is that greedy syntax will try to match as many possible repition of quantified patterns
as possible whereas non greedy will try to match few repition as possible"""
import re
print(re.findall("v*","vvvvvvv"))
print(re.findall("v*?","vvvvvvvv"))
# Out:
# ['vvvvvvv', '']
# ['', '', '', '', '', '', '', '', '']

# %%
"""Q2. When exactly does greedy versus non-greedy make a difference?  What if you're looking for a
non-greedy match but the only one available is greedy?
A = greedy syntex will try to match as many possible repition of quantified patters as possible while non greedy will look for few of the possible quantified syntax.
If there is only greedy method is available then we can use other methods from regex module"""
# Out:
# "Q2. When exactly does greedy versus non-greedy make a difference?\xa0 What if you're looking for a\nnon-greedy match but the only one available is greedy?\nA = greedy syntex will try to match as many possible repition of quantified patters as possible while non greedy will look for few of the possible quantified syntax.\nIf there is only greedy method is available then we can use other methods from regex module"

# %%
"""Q3. In a simple match of a string, which looks only for one match and does not do any replacement, is
the use of a nontagged group likely to make any practical difference?
A =in this case non tagged group will not make any significant difference."""
import re
phonenumber = re.compile(r'\d\d\d')
num = phonenumber.search("My phone number is --> 123-456-7890")
print(f'Phone number found -->',{num.group()})
print(f'Phone number found -->',{num.group(0)})
# Out:
# Phone number found --> {'123'}
# Phone number found --> {'123'}

# %%
"""Q4. Describe a scenario in which using a nontagged category would have a significant impact on the
program's outcomes.
A = here in below CODE SNIPPET . decimal is not tagged or captured.It will useful in scenario where seprator in string is of no use
and we need to capture only values"""
import re
text = "1323.6789"
pattern = r'(d\+)(?:.)(d\+)'
regobject = re.compile(pattern)
matobject = regobject.search(text)
matobject.groups()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-98136bca3093> in <module>
#       8 regobject = re.compile(pattern)
#       9 matobject = regobject.search(text)
# ---> 10 matobject.groups()
#
# AttributeError: 'NoneType' object has no attribute 'groups'

# %%
"""Q5. Unlike a normal regex pattern, a look-ahead condition does not consume the characters it
examines. Describe a situation in which this could make a difference in the results of your
programme.
A =while counting multiple line and multiple string look ahead condition makes a difference without which we won't get correct line or string count"""
# Out:
# "Q5. Unlike a normal regex pattern, a look-ahead condition does not consume the characters it\nexamines. Describe a situation in which this could make a difference in the results of your\nprogramme.\nA =while counting multiple line and multiple string look ahead condition makes a difference without which we won't get correct line or string count"

# %%
"""Q6. In standard expressions, what is the difference between positive look-ahead and negative look-
ahead?
A =POSITIVE look ahead will allow condition to check what follows.Negative look ahead is also similar but it allows to check backwards.
It allows to check only if there is matching pattern before it."""
# Out:
# 'Q6. In standard expressions, what is the difference between positive look-ahead and negative look-\nahead?\nA =POSITIVE look ahead will allow condition to check what follows.Negative look ahead is also similar but it allows to check backwards.\nIt allows to check only if there is matching pattern before it.'

# %%
"""Q7. What is the benefit of referring to groups by name rather than by number in a standard
expression?
A =referring groups by name rather than number is standard process to keep code clean and easily readable."""
# Out:
# 'Q7. What is the benefit of referring to groups by name rather than by number in a standard\nexpression?\nA =referring groups by name rather than number is standard process to keep code clean and easily readable.'

# %%
"""Q8. Can you identify repeated items within a target string using named groups, as in The cow
jumped over the moon?
A ="""
import re
string = "The cow jumped over the moon"
regobj = re.compile(r'(?p<w1>the)',re.I)
rejobj.findall(string)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-7bba8872264d> in <module>
#       4 import re
#       5 string = "The cow jumped over the moon"
# ----> 6 regobj = re.compile(r'(?p<w1>the)',re.I)
#       7 rejobj.findall(string)
#
# /srv/conda/envs/notebook/lib/python3.6/re.py in compile(pattern, flags)
#     231 def compile(pattern, flags=0):
#     232     "Compile a regular expression pattern, returning a pattern object."
# --> 233     return _compile(pattern, flags)
#     234
#     235 def purge():
#
# /srv/conda/envs/notebook/lib/python3.6/re.py in _compile(pattern, flags)
#     299     if not sre_compile.isstring(pattern):
#     300         raise TypeError("first argument must be string or compiled pattern")
# --> 301     p = sre_compile.compile(pattern, flags)
#     302     if not (flags & DEBUG):
#     303         if len(_cache) >= _MAXCACHE:
#
# ...

# %%
"""Q9. When parsing a string, what is at least one thing that the Scanner interface does for you that the
re.findall feature does not?
A =re.findall() used to match all occurence that match a given pattern.in contrast re.search() will return only first occurence.
re.findall() will iterate over whole file untile it finds all non overlaping patterns and retuns it"""
# Out:
# 'Q9. When parsing a string, what is at least one thing that the Scanner interface does for you that the\nre.findall feature does not?\nA =re.findall() used to match all occurence that match a given pattern.in contrast re.search() will return only first occurence.\nre.findall() will iterate over whole file untile it finds all non overlaping patterns and retuns it'

# %%
"""Q10. Does a scanner object have to be named scanner?
A = yes it may have any name"""
# Out:
# 'Q10. Does a scanner object have to be named scanner?\nA = yes it may have any name'
