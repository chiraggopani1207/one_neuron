# %%
"""Q1. What is the concept of a metaclass?
A =meta class in python is class of class which defines how it behaves.A class is itself instance of meta class and any instabnce of class in python
int,str,tuple,list and many more are metaclass 

"""
# Out:
# 'Q1. What is the concept of a metaclass?\nA =meta class in python is class of class which defines how it behaves.A class is itself instance of meta class and any instabnce of class in python\nint,str,tuple,list and many more are metaclass \n\n'

# %%
"""Q2. What is the best way to declare a class's metaclass?
A =by using metaclass in class can be used to define
"""
class meta(type):
    pass
class class_meta(metaclass=meta):
    pass
print(type(meta))
print(type(class_meta))
# Out:
# <class 'type'>
# <class '__main__.meta'>

# %%
"""Q3. How do class decorators overlap with metaclasses for handling classes?
A =Anything you can do with class decorators can be done with metaclass(just apply functionality of decorators) one that takes 
a class objects and modifies in the course of meta class __new__ or __init__ defines class object"""
# Out:
# 'Q3. How do class decorators overlap with metaclasses for handling classes?\nA =Anything you can do with class decorators can be done with metaclass(just apply functionality of decorators) one that takes \na class objects and modifies in the course of meta class __new__ or __init__ defines class object'

# %%
"""Q4. How do class decorators overlap with metaclasses for handling instances?
A =Anything you can do with a class decorator, you can of course do with a custom metaclass (just apply the functionality of the "decorator function", i.e., the one that takes a class object and modifies it, in the course of the metaclass's __new__ or __init__ that make the class object!)."""
# Out:
# 'Q4. How do class decorators overlap with metaclasses for handling instances?\nA =Anything you can do with a class decorator, you can of course do with a custom metaclass (just apply the functionality of the "decorator function", i.e., the one that takes a class object and modifies it, in the course of the metaclass\'s __new__ or __init__ that make the class object!).'
