# %%
"""Q1. What is the meaning of multiple inheritance?
A = inheritance is noting but using code of parent class by child class when child inherits properties from multiple 
parent class is called multiple inheritance
"""
class parent:
    pass
class guardian:
    pass
class child(parent,guardian):
    pass

# %%
"""Q2. What is the concept of delegation?
A =delegation provides proxy object on top of class that you want to use in main class . its like wrapper to your class so that you can access
limited resources of main class
it wraps object of main class into small instance with limited access

"""
class mycity:
    def name1(self):
        print("I'm mumbai city")
    def type1(self):
        print("i'm largest metro city of india")
class othercity:
    def __init__(self,obj):
        self.main=obj
    def welcome(self):
        self.main.name1()

# %%
m=mycity()
n=othercity(m)
m.name1()
n.main.name1()
# Out:
# I'm mumbai city
# I'm mumbai city

# %%
"""Q3. What is the concept of composition?
A = in the concept of composition one uses instances of multiple other class as instance variable
irrespective of inheritance all parent class objects are not inherited in child class
but only required method are used by instances"""
class salary:
    def __init__(self,pay):
        self.pay=pay
    def totatl_pay(self):
        return self.pay*12
class employee():
    def __init__(self,pay,bonus):
        self.pay=pay
        self.bonus=bonus
        self.obj_salary=salary(self.pay)
    def annual_salary(self):
        return f'total salary : {str(self.obj_salary.get_total())}

obj_emp = Employee(800,500)
print(obj_emp.annual_salary())

# %%
"""Q4. What are bound methods and how do we use them?
A =if function is attribute of class and is access through instances they are called bound methods
boound method has self as first argument"""
class trial:
    def method1(self):
        print("This is first method")
    @classmethod
    def method2(cls):
        print("This is second method")
    @staticmethod
    def method3():
        print("This is third method")
test=trial()
test.method1()
test.method2()
test.method3()

# %%
"""Q5. What is the purpose of pseudoprivate attributes?
A = Pseudoprivate attributes are also useful in larger frameworks or tools, both to avoid introducing new method names that might accidentally hide definitions elsewhere in the class tree and to reduce the chance of internal methods being replaced by names defined lower in the tree. If a method is intended for use only within a class that may be mixed into other classes, the double underscore prefix ensures that the method won't interfere with other names in the tree, especially in multiple-inheritance scenarios

Pseudoprivate names also prevent subclasses from accidentally redefining the internal method's names,"""
class Super:
    def method(self): # A real application method
        pass
class Tool:
    def _method(self): # becomes _Tool_method
        pass
    def other(self): # uses internal method
        self._method()
class Subl(Tool,Super):
    def actions(self):
        self.method()
class Sub2(Tool):
    def __init__(self):
        self.method = 99
