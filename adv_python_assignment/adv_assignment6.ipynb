# %%
"""Q1. Describe three applications for exception processing.
a = Exception processing is vey important to find exception that causes to run time error
as runtime error haults the programme when exception occured
1) checking appropriate use of input in application
2)checking arithmatic exception in mathematic application
3)cheking file i/o in file handling"""
# Out:
# 'Q1. Describe three applications for exception processing.\na = Exception processing is vey important to find exception that causes to run time error\nas runtime error haults the programme when exception occured\n1) checking appropriate use of input in application\n2)checking arithmatic exception in mathematic application\n3)cheking file i/o in file handling'

# %%
"""Q2. What happens if you don't do something extra to treat an exception?
A =if exception is not handled then it will restrict the flow of program will be broken during run time which might lead to abnormal termination of program.
inshort inability to handel exception will crash the program"""
# Out:
# "Q2. What happens if you don't do something extra to treat an exception?\nA =if exception is not handled then it will restrict the flow of program will be broken during run time which might lead to abnormal termination of program.\ninshort inability to handel exception will crash the program"

# %%
"""Q3. What are your options for recovering from an exception in your script?
A =python provide try and except to recover from exception script"""
# Out:
# 'Q3. What are your options for recovering from an exception in your script?\nA =python provide try and except to recover from exception script'

# %%
"""Q4. Describe two methods for triggering exceptions in your script.
A =raise and assert are two method to handel the exception in python
raise method will trigger if condition given in code comes true
assert method triggers if condition is not true exception will be raised"""
x = 10
raise exception(f'raise exception as provided value of x is not 5 but,{x}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6865cfaf5397> in <module>
#       4 assert method triggers if condition is not true exception will be raised"""
#       5 x = 10
# ----> 6 raise exception(f'raise exception as provided value of x is not 5 but,{x}')
#
# NameError: name 'exception' is not defined

# %%
"""Q5. Identify two methods for specifying actions to be executed at termination time, regardless of
whether or not an exception exists.
A =python provides else and finally block at the end of program to be executed regardless of wheather exception exist o not"""
# Out:
# 'Q5. Identify two methods for specifying actions to be executed at termination time, regardless of\nwhether or not an exception exists.\nA =python provides else and finally block at the end of program to be executed regardless of wheather exception exist o not'
