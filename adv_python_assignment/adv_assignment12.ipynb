# %%
"""Q1. Does assigning a value to a string's indexed character violate Python's string immutability?
A =String index character can not assign new value as strings are immutable"""
p = "Python3X"
print(id(p))
print(p[0])="r"
# Out:
#   File "<ipython-input-1-c8437a8d8b9a>", line 5
#     print(p[0])="r"
#                    ^
# SyntaxError: can't assign to function call

# %%
"""Q2. Does using the += operator to concatenate strings violate Python's string immutability? Why or
why not?
A =+= operator is used to concatenate string,it does not violates python's imutability string property
because creating new creates new association with data and variable"""
str_1 ="A"
print(id(str_1))
str_1 +="B"
print(id(str_1))
# Out:
# 140714782224088
# 140714680483152

# %%
"""Q3. In Python, how many different ways are there to index a character?
A =A character in string can be used by positive and negative indexing like in below examples"""
i ="I live my country INDIA"
print(i[0:13:1])
print(i[ : : -1])
# Out:
# I live my cou
# AIDNI yrtnuoc ym evil I

# %%
"""Q4. What is the relationship between indexing and slicing?
A =we can access element of sequential data types in string by slicing and indexing .Indexing is used to obtain individual object and slicing is used to get sequential data"""
i ="I try to learn Python"
print(i[0])
print(i[1:])
# Out:
# I
#  try to learn Python

# %%
"""Q5. What is an indexed character's exact data type? What is the data form of a slicing-generated
substring?
A =index character and slicing substring has data type string"""
i ="I try to learn Python"
print(type(i[0]))
print(type(i[1:]))
# Out:
# <class 'str'>
# <class 'str'>

# %%
"""What is the relationship between string and character "types" in Python?
A =object that contains sequential data type are called string"""
# Out:
# 'What is the relationship between string and character "types" in Python?\nA =object that contains sequential data type are called string'

# %%
"""Q7. Identify at least two operators and one method that allow you to combine one or more smaller
strings to create a larger string.
A =+,+= and * are methods that allow you to combine one or more smalled strings to create large string
"""
x = "python"
y ="machine learning"
print(x + y)
print(x * 3)
print((" ".join("Data science")).lower())
# Out:
# pythonmachine learning
# pythonpythonpython
# d a t a   s c i e n c e

# %%
"""Q8. What is the benefit of first checking the target string with in or not in before using the index
method to find a substring?
A =checking target string with in or not before using the index method to find substring just helps confirming availibilty of substring
thus avoiding value error"""
a = "spider-man -- no way home"
print("home" in a)
print("zombies" not in a)
# Out:
# True
# True

# %%
"""Q9. Which operators and built-in string methods produce simple Boolean (true/false) results?
A = The String Operators and built-in methods to Produce Simple Boolean (True/False) Results are:

in
not
<string>.isalpha()
<string>.isalnum()
<string>.isdecimal()
<string>.isdigit()
<string>.islower()
<string>.isnumeric()
<string>.isprintable()
<string>.isspace()
<string>.istitle()"""
# Out:
# 'Q9. Which operators and built-in string methods produce simple Boolean (true/false) results?\nA = The String Operators and built-in methods to Produce Simple Boolean (True/False) Results are:\n\nin\nnot\n<string>.isalpha()\n<string>.isalnum()\n<string>.isdecimal()\n<string>.isdigit()\n<string>.islower()\n<string>.isnumeric()\n<string>.isprintable()\n<string>.isspace()\n<string>.istitle()'
