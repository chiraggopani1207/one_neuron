# %%
"""Q1. What are the two latest user-defined exception constraints in Python 3.X?
A =raise and assert are two new user definer constraint in python 3.x"""
# Out:
# 'Q1. What are the two latest user-defined exception constraints in Python 3.X?\nA =raise and assert are two new user definer constraint in python 3.x'

# %%
"""Q2. How are class-based exceptions that have been raised matched to handlers?
A =in python user can define custom class based exception.This exception class has to be derived either directly or indirectly from built in function
exception class.this new exception class can be raised like other class throgh raise statement with optional error message"""
class toyoungexception:
    def __init__(self,msg):
        self.msg=msg
age =12
if age<18: raise toyoungexception("not eligible to participate")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-24e8ed9ebb48> in <module>
#       6         self.msg=msg
#       7 age =12
# ----> 8 if age<18: raise toyoungexception("not eligible to participate")
#
# TypeError: exceptions must derive from BaseException

# %%
"""Q3. Describe two methods for attaching context information to exception artefacts.
A =The process() method of loggeradapter where context information of exception is stored.it passes message and keyword argument
of the logging call and passes back the modified version of this to use in underlying call object.
other method used is exception() logs a error with logging error message.argument are interpretaed as debug()
exception info is added to logging method"""
# Out:
# 'Q3. Describe two methods for attaching context information to exception artefacts.\nA =The process() method of loggeradapter where context information of exception is stored.it passes message and keyword argument\nof the logging call and passes back the modified version of this to use in underlying call object.\nother method used is exception() logs a error with logging error message.argument are interpretaed as debug()\nexception info is added to logging method'

# %%
"""Q4. Describe two methods for specifying the text of an exception object&#39;s error message.
A =raise and assert are two mrthod to specifying text of exception object's error message.
raise methos is used to raise explicit exception.if certain condition is not as per requirement then it helps in raising exception.
ther are few assertion always thee to avode the failure of code to run any time.this kind of statement requires assert statement.
assert statement takes boolean value if true program continues and if false then assertion error ill display"""
# Out:
# "Q4. Describe two methods for specifying the text of an exception object&#39;s error message.\nA =raise and assert are two mrthod to specifying text of exception object's error message.\nraise methos is used to raise explicit exception.if certain condition is not as per requirement then it helps in raising exception.\nther are few assertion always thee to avode the failure of code to run any time.this kind of statement requires assert statement.\nassert statement takes boolean value if true program continues and if false then assertion error ill display"

# %%
"""Q5. Why do you no longer use string-based exceptions?
A =string exception doesn't inherit from exception and plain exception catches all exception and not only exception"""
# Out:
# "Q5. Why do you no longer use string-based exceptions?\nA =string exception doesn't inherit from exception and plain exception catches all exception and not only exception"
