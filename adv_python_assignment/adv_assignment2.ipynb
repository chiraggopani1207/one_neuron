# %%
"""Q1. What is the relationship between classes and modules?
A =PYTHON CLASS IS BLUEPRINT/OUTLINE/MOLD FOR CREATING A NEW OBJECT.AN OBJECT IS ANYTHING YOU WISH TO MANIPULATE THROUGH CODE
EVERY TIME CLASS OBJECT IS INTIATED WHICH IS WHEN WE DECLARE VARIABLE A NEW OBJECT IS INTIATED FROM SCRATCH
WHEREAS PYTHON MODULE ARE .PY FILES WHICH ARE IMPORTED INSIDE CURRENT WORKING CODE FILE.IN SIMPLE TERMS MODULES ARE PRE CREATED CODES
OF PYTHON IN LIBRARY WHEN NEED ARISES WE CAN IMPORT THOSE CODE """
# Out:
# 'Q1. What is the relationship between classes and modules?\nA =PYTHON CLASS IS BLUEPRINT/OUTLINE/MOLD FOR CREATING A NEW OBJECT.AN OBJECT IS ANYTHING YOU WISH TO MANIPULATE THROUGH CODE\nEVERY TIME CLASS OBJECT IS INTIATED WHICH IS WHEN WE DECLARE VARIABLE A NEW OBJECT IS INTIATED FROM SCRATCH\nWHEREAS PYTHON MODULE ARE .PY FILES WHICH ARE IMPORTED INSIDE CURRENT WORKING CODE FILE.IN SIMPLE TERMS MODULES ARE PRE CREATED CODES\nOF PYTHON IN LIBRARY WHEN NEED ARISES WE CAN IMPORT THOSE CODE '

# %%
"""Q2. How do you make instances and classes?
find the below example for class and instances"""
class student1:
    def __init__(self,name,subject):
        self.name=name
        self.subject=subject

# %%
sagar=student1("sagar","science")

# %%
"""Q3. Where and how should be class attributes created?
A =class attributes or class level attributes are created seperately in class which is used by all instances of class.
hence its defined in top of the class outside all methods
find below example of class attribute"""
# Out:
# 'Q3. Where and how should be class attributes created?\nA =class attributes or class level attributes are created seperately in class which is used by all instances of class.\nhence its defined in top of the class outside all methods\nfind below example of class attribute'

# %%
class car:
    wheels =4 #this is class attribute
    def __init__(self,name,brand,price):
        self.name=name
        self.brand=brand
        self.price=price

# %%
"""Q4. Where and how are instance attributes created?
A = Instances attributes are passed to the class when an object of the class is created. Unlike class attributes, instance attributes are not shared by all objects of the classs. instead each object maintains its own copy of instance attributes at object level. whereas incase of class attributes all instances of class refer to a single copy. Usually instance attributes are defined within the __init__ method of class"""
tata =car("nexon","tata",50000)

# %%
tata.name
# Out:
# 'nexon'

# %%
tata.brand
# Out:
# 'tata'

# %%
tata.price
# Out:
# 50000

# %%
"""Q5. What does the term 'self' in a Python class mean?
A =self represent the object we created inside the class. by using self keyword we can access the object attributes and methods of class
it binds the attribute with given argument.
"""
# Out:
# "Q5. What does the term 'self' in a Python class mean?\nA =self represent the object we created inside the class. by using self keyword we can access the object attributes and methods of class\nit binds the attribute with given argument.\n"

# %%
"""Q6. How does a Python class handle operator overloading?
A = + --> __add__()
    - --> __substract()
    * --> __multiply__()
    / --> __division__()
    """
class veg:
    def __init__(self,kg):
        self.kg=kg
    def __add__(self,addmore):
        return self.kg +addmore.kg
vendor1 =(5)
vendor2 =(7)
total =(f'total tomatoes purchaed from both vendors is {vendor1+vendor2} kg')

# %%
print(total)
# Out:
# total tomatoes purchaed from both vendors is 12 kg

# %%
"""Q7. When do you consider allowing operator overloading of your classes?
A= when we have to use operator for different meaning then we can use operator overloading"""
# Out:
# 'Q7. When do you consider allowing operator overloading of your classes?\nA= when we have to use operator for different meaning then we can use operator overloading'

# %%
"""Q8. What is the most popular form of operator overloading?
A =most popular overloading method is __magic__ method in python oop"""
# Out:
# 'Q8. What is the most popular form of operator overloading?\nA =most popular overloading method is __magic__ method in python oop'

# %%
"""Q9. What are the two most important concepts to grasp in order to comprehend Python OOP code?
A =class and object are two most important concept in oop in python
along with this inheritence,encapsulation,polymorphism,abstraction are some other"""
# Out:
# 'Q9. What are the two most important concepts to grasp in order to comprehend Python OOP code?\nA =class and object are two most important concept in oop in python\nalong with this inheritence,encapsulation,polymorphism,abstraction are some other'
