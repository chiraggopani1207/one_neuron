# %%
"""1. What advantages do Excel spreadsheets have over CSV spreadsheets?
A = EXCEL FILES(.XLS) and (.XLXS) files are better for storing large and complex data
in excel file we can perform multiple fuction using formulas ans macros
.csv file are similar to text file similar to word"""
# Out:
# '1. What advantages do Excel spreadsheets have over CSV spreadsheets?\nA = EXCEL FILES(.XLS) and (.XLXS) files are better for storing large and complex data\nin excel file we can perform multiple fuction using formulas ans macros\n.csv file are similar to text file similar to word'

# %%
"""2.What do you pass to csv.reader() and csv.writer() to create reader and writer objects?
A =with open("first.csv") as file:
    csv_file=csv.reader(file,delimiter','')
    for ele in csv_file:
        print(ele)"""
# Out:
# '2.What do you pass to csv.reader() and csv.writer() to create reader and writer objects?\nA =with open("first.csv") as file:\n    csv_file=csv.reader(file,delimiter\',\'\')\n    for ele in csv_file:\n        print(ele)'

# %%
"""3. What modes do File objects for reader and writer objects need to be opened in?
A = for cs.reader(iterable_file_object) should be open in 'r' read mode and for csv.writer(iterable_file_object) should be open in 'w' write mode"""
# Out:
# "3. What modes do File objects for reader and writer objects need to be opened in?\nA = for cs.reader(iterable_file_object) should be open in 'r' read mode and for csv.writer(iterable_file_object) should be open in 'w' write mode"

# %%
"""4. What method takes a list argument and writes it to a CSV file?
A =import csv
field=["name","stream","percentage","year"]
row=[
    ['chirag','commerce','75','2013'],
    ['ram','science','80','2014'],
    ['shyam','arts','85','2015']
]
with open("college_rec.csv") as csvfile:
    csvwriter=csv.write(csvfile)
    csvwriter=csv.writerow(field)
    csvwriter=csv.writerow(row)"""
# Out:
# '4. What method takes a list argument and writes it to a CSV file?\nA =import csv\nfield=["name","stream","percentage","year"]\nrow=[\n    [\'chirag\',\'commerce\',\'75\',\'2013\'],\n    [\'ram\',\'science\',\'80\',\'2014\'],\n    [\'shyam\',\'arts\',\'85\',\'2015\']\n]\nwith open("college_rec.csv") as csvfile:\n    csvwriter=csv.write(csvfile)\n    csvwriter=csv.writerow(field)\n    csvwriter=csv.writerow(row)'

# %%
"""5. What do the keyword arguments delimiter and line terminator do?
A =in below example:
chirag,bms,30
ram,b.tech,25
in first row delimiter is ',' and line terminator comes at end whhich is default \n and we can change it"""
# Out:
# "5. What do the keyword arguments delimiter and line terminator do?\nA =in below example:\nchirag,bms,30\nram,b.tech,25\nin first row delimiter is ',' and line terminator comes at end whhich is default \n and we can change it"

# %%
"""6. What function takes a string of JSON data and returns a Python data structure?
A =loads() method take string of JSON and returns python data structure"""
# Out:
# '6. What function takes a string of JSON data and returns a Python data structure?\nA =loads() method take string of JSON and returns python data structure'

# %%
"""7. What function takes a Python data structure and returns a string of JSON data?
A =dumps() take python data structure  and returns string of JSON data """
# Out:
# '7. What function takes a Python data structure and returns a string of JSON data?\nA =dumps() take python data structure  and returns string of JSON data '
