# %%
"""Q =1. Why are functions advantageous to have in your programs?
A = You can define code inside custom function.so you can resue it whenever you required."""
# Out:
# 'Q =1. Why are functions advantageous to have in your programs?\nA = You can define code inside custom function.so you can resue it whenever you required.'

# %%
"""2. When does the code in a function run: when run : specified or when its called?
A =When run function called it execute the code in ide"""
# Out:
# '2. When does the code in a function run: when run : specified or when its called?\nA =When run function called it execute the code in ide'

# %%
"""3. What statement creates a function?
A = to create user define function : 
def fun1(a,b):
    "docstring"
    function 
    return a+b"""
# Out:
# '3. What statement creates a function?\nA = to create user define function : \ndef fun1(a,b):\n    "docstring"\n    function \n    return a+b'

# %%
"""4. What is the difference between a function and a function call?
A = function is predefined rules while function call is used to run then predefine function to execute any program."""
# Out:
# '4. What is the difference between a function and a function call?\nA = function is predefined rules while function call is used to run then predefine function to execute any program.'

# %%
"""5. How many global scopes are there in a Python program? How many local scopes?
A = there is one global scope and local scope run as many time as you want when its called"""
# Out:
# '5. How many global scopes are there in a Python program? How many local scopes?\nA = there is one global scope and local scope run as many time as you want when its called'

# %%
"""6. What happens to variables in a local scope when the function call returns?
A = When function call return the it removes all local scopes and forget values inside variables."""
# Out:
# '6. What happens to variables in a local scope when the function call returns?\nA = When function call return the it removes all local scopes and forget values inside variables.'

# %%
"""7. What is the concept of a return value? Is it possible to have a return value in an expression?
A = please check in below function example for more clarity."""
def fun1(a,b):
    return a*b

# %%
fun1(4,5)
# Out:
# 20

# %%
"""8. If a function does not have a return statement, what is the return value of a call to that function?
A = return value statement == none"""
# Out:
# '8. If a function does not have a return statement, what is the return value of a call to that function?\nA = return value statement == none'

# %%
""" 9. How do you make a function variable refer to the global variable?
A = user must define global variable in advance"""
# Out:
# ' 9. How do you make a function variable refer to the global variable?\nA = user must define global variable in advance'

# %%
"""10. What is the data type of None?
A = NONETYPE"""
# Out:
# '10. What is the data type of None?\nA = NONETYPE'

# %%
"""11. What does the sentence import areallyourpetsnamederic do?
A = it will import areallyourpetsnamederic only if  it exist"""
# Out:
# '11. What does the sentence import areallyourpetsnamederic do?\nA = it will import areallyourpetsnamederic only if  it exist'

# %%
"""12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
A = spam.bacon()"""
# Out:
# '12. If you had a bacon() feature in a spam module, what would you call it after importing spam?\nA = spam.bacon()'

# %%
"""13. What can you do to save a programme from crashing if it encounters an error?
A = you can use try: and except : function to avoide rest of the program get crashed"""
# Out:
# '13. What can you do to save a programme from crashing if it encounters an error?\nA = you can use try: and except : function to avoide rest of the program get crashed'

# %%
"""14. What is the purpose of the try clause? What is the purpose of the except clause?
A = its generally used to avoide possible error in code. any potential error causing lines will go in try clause and if it finds error it will execute except clause."""
# Out:
# '14. What is the purpose of the try clause? What is the purpose of the except clause?\nA = its generally used to avoide possible error in code. any potential error causing lines will go in try clause and if it finds error it will execute except clause.'
