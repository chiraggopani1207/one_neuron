# %%
"""1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?
A =for pdffileReader() file should be open in 'rb' read binary mode and for pdfFilewriter() file should be open in 'wb' write binary mode"""
# Out:
# "1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?\nA =for pdffileReader() file should be open in 'rb' read binary mode and for pdfFilewriter() file should be open in 'wb' write binary mode"

# %%
"""2. From a PdfFileReader object, how do you get a Page object for page 5?
A =pdffilereader class provides getpade(page_no) function to get pagess
from pypdf import pdfFileReader
pdfFileReader = pdfFileReader(file path)
for page in pdfReader.getpages(num_pages)
    pdfReader.getpages(page_no)"""
# Out:
# '2. From a PdfFileReader object, how do you get a Page object for page 5?\nA =pdffilereader class provides getpade(page_no) function to get pagess\nfrom pypdf import pdfFileReader\npdfFileReader = pdfFileReader(file path)\nfor page in pdfReader.getpages(num_pages)\n    pdfReader.getpages(page_no)'

# %%
"""3. What PdfFileReader variable stores the number of pages in the PDF document?
A =getNumpages() stores number of pages """
# Out:
# '3. What PdfFileReader variable stores the number of pages in the PDF document?\nA =getNumpages() stores number of pages '

# %%
"""4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do
before you can obtain Page objects from it?
A =if pdf file is encrypted with password swordfish and you are not aware of it then open file in pdfread mode
pdfreader class attribute will show you whether file in encrypted
if file is encrypted then use decrypt() method first and then try to read file
from PYPDF2 import PdfFileReader
pdf_reader =PdfFilereader(path)
if pdfFile. isEncrypted:
   pdfReader.decrypt("swordfish")
for page in pdf_reader.pages:
    print(page.extracttext())
    """
# Out:
# '4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do\nbefore you can obtain Page objects from it?\nA =if pdf file is encrypted with password swordfish and you are not aware of it then open file in pdfread mode\npdfreader class attribute will show you whether file in encrypted\nif file is encrypted then use decrypt() method first and then try to read file\nfrom PYPDF2 import PdfFileReader\npdf_reader =PdfFilereader(path)\nif pdfFile. isEncrypted:\n   pdfReader.decrypt("swordfish")\nfor page in pdf_reader.pages:\n    print(page.extracttext())\n    '

# %%
"""5. What methods do you use to rotate a page?
A =rotateClockwise() and rotateCounterClockwise()"""
# Out:
# '5. What methods do you use to rotate a page?\nA =rotateClockwise() and rotateCounterClockwise()'

# %%
"""6. What is the difference between a Run object and a Paragraph object?
A =the structured data set in file is represnted by 3 main attributes in docx file
at highest level document is represted by entire document 
a document object represt list of paragraphs new paragraph created when user hits enter or return"""
# Out:
# '6. What is the difference between a Run object and a Paragraph object?\nA =the structured data set in file is represnted by 3 main attributes in docx file\nat highest level document is represted by entire document \na document object represt list of paragraphs new paragraph created when user hits enter or return'

# %%
"""7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable
named doc?
A =from docx import paragraph
doc =document("newfile.txt")
print(doc.paragraph)
for paragraph in doc.paragraph:
    print(paragraph.text)"""
# Out:
# '7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable\nnamed doc?\nA =from docx import paragraph\ndoc =document("newfile.txt")\nprint(doc.paragraph)\nfor paragraph in doc.paragraph:\n    print(paragraph.text)'

# %%
"""8. What type of object has bold, underline, italic, strike, and outline variables?
A =Run object has attributes like bold,underline,italic,strike and outline"""
# Out:
# '8. What type of object has bold, underline, italic, strike, and outline variables?\nA =Run object has attributes like bold,underline,italic,strike and outline'

# %%
"""9. What is the difference between False, True, and None for the bold variable?
A = False - style not set to bold
True -style set to bold
None - style attribute not applicable"""
# Out:
# '9. What is the difference between False, True, and None for the bold variable?\nA = False - style not set to bold\nTrue -style set to bold\nNone - style attribute not applicable'

# %%
"""10. How do you create a Document object for a new Word document?
A =from Docx import document
doc = document()
doc.addparagraph("hello everyone")
doc.save("mydocument.txt")
"""
# Out:
# '10. How do you create a Document object for a new Word document?\nA =from Docx import document\ndoc = document()\ndoc.addparagraph("hello everyone")\ndoc.save("mydocument.txt")\n'

# %%
"""11. How do you add a paragraph with the text 'Hello, there!'' to a Document object stored in a
variable named doc?
A =from Docx import document
doc=document()
doc.addparagraph("i\'m king of the world")
doc.save("chirag.txt")"""
# Out:
# '11. How do you add a paragraph with the text \'Hello, there!\'\' to a Document object stored in a\nvariable named doc?\nA =from Docx import document\ndoc=document()\ndoc.addparagraph("i\'m king of the world")\ndoc.save("chirag.txt")'

# %%
"""12. What integers represent the levels of headings available in Word documents?
A =The levels for a heading in a word document can be specified by using the level attribute inside the add_heading method. There are a total of 5 levels statring for 0 t0 4. where level 0 makes a headline with the horizontal line below the text, whereas the heading level 1 is the main heading. Similarly, the other headings are sub-heading with their's font-sizes in decreasing order."""
# Out:
# "12. What integers represent the levels of headings available in Word documents?\nA =The levels for a heading in a word document can be specified by using the level attribute inside the add_heading method. There are a total of 5 levels statring for 0 t0 4. where level 0 makes a headline with the horizontal line below the text, whereas the heading level 1 is the main heading. Similarly, the other headings are sub-heading with their's font-sizes in decreasing order."
